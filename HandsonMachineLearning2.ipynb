# %% [markdown]
# ## Chapter 2 – End-to-End Machine Learning Project

# %%
import sys

assert sys.version_info >= (3, 10)

# %%
from packaging.version import Version
import sklearn

assert Version(sklearn.__version__) >= Version("1.6.1")

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets", filter="data")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing_full = load_housing_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 16
#      13             housing_tarball.extractall(path="datasets", filter="data")
#      14     return pd.read_csv(Path("datasets/housing/housing.csv"))
# ---> 16 housing_full = load_housing_data()
#
# Cell In[3], line 13, in load_housing_data()
#      11     urllib.request.urlretrieve(url, tarball_path)
#      12     with tarfile.open(tarball_path) as housing_tarball:
# ---> 13         housing_tarball.extractall(path="datasets", filter="data")
#      14 return pd.read_csv(Path("datasets/housing/housing.csv"))
#
# TypeError: TarFile.extractall() got an unexpected keyword argument 'filter'
